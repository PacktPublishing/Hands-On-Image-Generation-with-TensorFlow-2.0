# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Reshape, Conv2DTranspose, MaxPooling2D, UpSampling2D, LeakyReLU
from tensorflow.keras.activations import relu
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import tensorflow_datasets as tfds

import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
print("Tensorflow", tf.__version__)
# Out:
# Tensorflow 2.2.0

# %% [markdown]
# ## Load MNIST dataset

# %%
(ds_train, ds_test_), ds_info = tfds.load('mnist', 
                              split=['train', 'test'], 
                              shuffle_files=True,
                              as_supervised=True,
                              with_info=True)


batch_size = 256
def preprocess(image, label):
    image = tf.cast(image, tf.float32)
    image = image/255.
    return image, image


ds_train = ds_train.map(preprocess)
ds_train = ds_train.cache() # put dataset into memory
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(batch_size)

ds_test = ds_test_.map(preprocess).batch(batch_size).cache().prefetch(batch_size)

# %%
# return label for testing
def preprocess_with_label(image, label):
    image = tf.cast(image, tf.float32)
    image = tf.math.round(image/255.)
    return image, label

ds_test_label = ds_test_.map(preprocess_with_label).batch(1000)

# %% [markdown]
# # Building Autoencoder

# %%
def Encoder(z_dim):
    inputs  = layers.Input(shape=[28,28,1])
    
    x = inputs    
    x = Conv2D(filters=8,  kernel_size=(3,3), strides=2, padding='same', activation='relu')(x)
    x = Conv2D(filters=8,  kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
    x = Conv2D(filters=8,  kernel_size=(3,3), strides=2, padding='same', activation='relu')(x)
    x = Conv2D(filters=8,  kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
    x = Flatten()(x)
    out = Dense(z_dim)(x)
    
    return Model(inputs=inputs, outputs=out, name='encoder')

def Decoder(z_dim):
    inputs  = layers.Input(shape=[z_dim])
    x = inputs    
    x = Dense(7*7*64, activation='relu')(x)
    x = Reshape((7,7,64))(x)

    x = Conv2D(filters=64, kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
    x = UpSampling2D((2,2))(x)
    
    x = Conv2D(filters=32, kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
    x = UpSampling2D((2,2))(x)    

    out = Conv2D(filters=1, kernel_size=(3,3), strides=1, padding='same', activation='sigmoid')(x)
    
    #return out          
    return Model(inputs=inputs, outputs=out, name='decoder')

class Autoencoder:
    def __init__(self, z_dim):
        self.encoder = Encoder(z_dim)
        self.decoder = Decoder(z_dim)
        
        model_input = self.encoder.input
        model_output = self.decoder(self.encoder.output)
        self.model = Model(model_input, model_output)

# %%
autoencoder = Autoencoder(z_dim=10)

# %%
model_path = "./models/autoencoder.h5"
checkpoint = ModelCheckpoint(model_path, 
                             monitor= "val_loss", 
                             verbose=1, 
                             save_best_only=True, 
                             mode= "auto", 
                             save_weights_only = False)

early = EarlyStopping(monitor= "val_loss", 
                      mode= "auto", 
                      patience = 5)

callbacks_list = [checkpoint, early]

autoencoder.model.compile(
    loss = "mse",
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=3e-4))
    #metrics=[tf.keras.losses.BinaryCrossentropy()])
autoencoder.model.fit(ds_train, validation_data=ds_test,
                epochs = 100, callbacks = callbacks_list)
# Out:
# Epoch 1/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0656
# Epoch 00001: val_loss improved from inf to 0.04128, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0656 - val_loss: 0.0413
# Epoch 2/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.0349
# Epoch 00002: val_loss improved from 0.04128 to 0.02908, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0349 - val_loss: 0.0291
# Epoch 3/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.0278
# Epoch 00003: val_loss improved from 0.02908 to 0.02624, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0277 - val_loss: 0.0262
# Epoch 4/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.0246
# Epoch 00004: val_loss improved from 0.02624 to 0.02269, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0246 - val_loss: 0.0227
# Epoch 5/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.0228
# Epoch 00005: val_loss improved from 0.02269 to 0.02162, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0228 - val_loss: 0.0216
# Epoch 6/100
# 235/235 [==============================] - ETA: 0s - loss: 0.0216
# Epoch 00006: val_loss improved from 0.02162 to 0.02139, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0216 - val_loss: 0.0214
# Epoch 7/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.0207
# Epoch 00007: val_loss improved from 0.02139 to 0.02004, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0207 - val_loss: 0.0200
# Epoch 8/100
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0200
# Epoch 00008: val_loss improved from 0.02004 to 0.01943, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0200 - val_loss: 0.0194
# Epoch 9/100
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0195
# Epoch 00009: val_loss improved from 0.01943 to 0.01940, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0195 - val_loss: 0.0194
# Epoch 10/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0190
# Epoch 00010: val_loss improved from 0.01940 to 0.01838, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0190 - val_loss: 0.0184
# Epoch 11/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0186
# Epoch 00011: val_loss did not improve from 0.01838
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0186 - val_loss: 0.0184
# Epoch 12/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0182
# Epoch 00012: val_loss improved from 0.01838 to 0.01814, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0182 - val_loss: 0.0181
# Epoch 13/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0179
# Epoch 00013: val_loss improved from 0.01814 to 0.01783, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0179 - val_loss: 0.0178
# Epoch 14/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0176
# Epoch 00014: val_loss improved from 0.01783 to 0.01715, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0176 - val_loss: 0.0171
# Epoch 15/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0174
# Epoch 00015: val_loss improved from 0.01715 to 0.01694, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0174 - val_loss: 0.0169
# Epoch 16/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0171
# Epoch 00016: val_loss did not improve from 0.01694
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0171 - val_loss: 0.0177
# Epoch 17/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0169
# Epoch 00017: val_loss did not improve from 0.01694
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0169 - val_loss: 0.0174
# Epoch 18/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0167
# Epoch 00018: val_loss improved from 0.01694 to 0.01653, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0167 - val_loss: 0.0165
# Epoch 19/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0165
# Epoch 00019: val_loss did not improve from 0.01653
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0165 - val_loss: 0.0168
# Epoch 20/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0164
# Epoch 00020: val_loss did not improve from 0.01653
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0164 - val_loss: 0.0167
# Epoch 21/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0162
# Epoch 00021: val_loss improved from 0.01653 to 0.01623, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0162 - val_loss: 0.0162
# Epoch 22/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0161
# Epoch 00022: val_loss improved from 0.01623 to 0.01616, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0161 - val_loss: 0.0162
# Epoch 23/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0159
# Epoch 00023: val_loss improved from 0.01616 to 0.01605, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0159 - val_loss: 0.0160
# Epoch 24/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0158
# Epoch 00024: val_loss improved from 0.01605 to 0.01556, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0158 - val_loss: 0.0156
# Epoch 25/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0156
# Epoch 00025: val_loss improved from 0.01556 to 0.01550, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0156 - val_loss: 0.0155
# Epoch 26/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0155
# Epoch 00026: val_loss did not improve from 0.01550
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0155 - val_loss: 0.0156
# Epoch 27/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0154
# Epoch 00027: val_loss did not improve from 0.01550
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0154 - val_loss: 0.0156
# Epoch 28/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0153
# Epoch 00028: val_loss did not improve from 0.01550
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0153 - val_loss: 0.0156
# Epoch 29/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0152
# Epoch 00029: val_loss improved from 0.01550 to 0.01539, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0152 - val_loss: 0.0154
# Epoch 30/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.0151
# Epoch 00030: val_loss improved from 0.01539 to 0.01521, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0151 - val_loss: 0.0152
# Epoch 31/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0150
# Epoch 00031: val_loss improved from 0.01521 to 0.01508, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0150 - val_loss: 0.0151
# Epoch 32/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0149
# Epoch 00032: val_loss did not improve from 0.01508
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0149 - val_loss: 0.0153
# Epoch 33/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0148
# Epoch 00033: val_loss did not improve from 0.01508
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0148 - val_loss: 0.0152
# Epoch 34/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0147
# Epoch 00034: val_loss improved from 0.01508 to 0.01490, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0148 - val_loss: 0.0149
# Epoch 35/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0147
# Epoch 00035: val_loss did not improve from 0.01490
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0147 - val_loss: 0.0150
# Epoch 36/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0146
# Epoch 00036: val_loss improved from 0.01490 to 0.01476, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0146 - val_loss: 0.0148
# Epoch 37/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.0145
# Epoch 00037: val_loss did not improve from 0.01476
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0145 - val_loss: 0.0149
# Epoch 38/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0145
# Epoch 00038: val_loss did not improve from 0.01476
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0145 - val_loss: 0.0150
# Epoch 39/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0144
# Epoch 00039: val_loss improved from 0.01476 to 0.01460, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0144 - val_loss: 0.0146
# Epoch 40/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0143
# Epoch 00040: val_loss did not improve from 0.01460
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0143 - val_loss: 0.0146
# Epoch 41/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0143
# Epoch 00041: val_loss did not improve from 0.01460
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0143 - val_loss: 0.0150
# Epoch 42/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0142
# Epoch 00042: val_loss did not improve from 0.01460
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0142 - val_loss: 0.0146
# Epoch 43/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0141
# Epoch 00043: val_loss improved from 0.01460 to 0.01436, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0141 - val_loss: 0.0144
# Epoch 44/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0141
# Epoch 00044: val_loss improved from 0.01436 to 0.01431, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0141 - val_loss: 0.0143
# Epoch 45/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.0140
# Epoch 00045: val_loss improved from 0.01431 to 0.01405, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0140 - val_loss: 0.0141
# Epoch 46/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0140
# Epoch 00046: val_loss did not improve from 0.01405
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0140 - val_loss: 0.0144
# Epoch 47/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0139
# Epoch 00047: val_loss did not improve from 0.01405
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0139 - val_loss: 0.0142
# Epoch 48/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0139
# Epoch 00048: val_loss did not improve from 0.01405
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0139 - val_loss: 0.0143
# Epoch 49/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.0138
# Epoch 00049: val_loss did not improve from 0.01405
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0138 - val_loss: 0.0143
# Epoch 50/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.0138
# Epoch 00050: val_loss did not improve from 0.01405
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0138 - val_loss: 0.0146

# %% [markdown]
# # Sample and Display Images

# %%
images, labels = next(iter(ds_test))
autoencoder.model = load_model(model_path)
outputs = autoencoder.model.predict(images)

# Display
grid_col = 10
grid_row = 2

f, axarr = plt.subplots(grid_row, grid_col, figsize=(grid_col*1.1, grid_row))

i = 0
for row in range(0, grid_row, 2):
    for col in range(grid_col):
        axarr[row,col].imshow(images[i,:,:,0], cmap='gray')
        axarr[row,col].axis('off')
        axarr[row+1,col].imshow(outputs[i,:,:,0], cmap='gray')
        axarr[row+1,col].axis('off')        
        i += 1
f.tight_layout(0.1, h_pad=0.2, w_pad=0.1)        
plt.show()

# %% [markdown]
# ## Set z_dim = 2 and to look at the latent variables

# %%
autoencoder_2 = Autoencoder(z_dim=2)

early = EarlyStopping(monitor= "val_loss", 
                      mode= "auto", 
                      patience = 5)

callbacks_list = [early]

autoencoder_2.model.compile(
    loss = "mse",
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-3))

autoencoder_2.model.fit(ds_train, validation_data=ds_test,
                epochs = 50, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0634 - val_loss: 0.0549
# Epoch 2/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0519 - val_loss: 0.0498
# Epoch 3/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0494 - val_loss: 0.0490
# Epoch 4/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0478 - val_loss: 0.0476
# Epoch 5/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0467 - val_loss: 0.0463
# Epoch 6/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0459 - val_loss: 0.0458
# Epoch 7/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0453 - val_loss: 0.0455
# Epoch 8/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0447 - val_loss: 0.0451
# Epoch 9/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0443 - val_loss: 0.0441
# Epoch 10/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0439 - val_loss: 0.0436
# Epoch 11/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0436 - val_loss: 0.0441
# Epoch 12/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0433 - val_loss: 0.0442
# Epoch 13/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0431 - val_loss: 0.0428
# Epoch 14/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0429 - val_loss: 0.0430
# Epoch 15/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0427 - val_loss: 0.0426
# Epoch 16/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0425 - val_loss: 0.0426
# Epoch 17/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0424 - val_loss: 0.0432
# Epoch 18/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0422 - val_loss: 0.0423
# Epoch 19/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0421 - val_loss: 0.0422
# Epoch 20/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0420 - val_loss: 0.0417
# Epoch 21/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0419 - val_loss: 0.0419
# Epoch 22/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0417 - val_loss: 0.0419
# Epoch 23/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0416 - val_loss: 0.0418
# Epoch 24/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0415 - val_loss: 0.0419
# Epoch 25/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0414 - val_loss: 0.0418

# %%
images, labels = next(iter(ds_test_label))
outputs = autoencoder_2.encoder.predict(images)
plt.figure(figsize=(8,8))
plt.scatter(outputs[:,0], outputs[:,1], c=labels, cmap='RdYlBu', s=3)
plt.colorbar()

# %%
z_samples = np.array([[z1, z2] for z2 in np.arange(-5, 5, 1.) for z1 in np.arange(-5, 5, 1.)])
images = autoencoder_2.decoder.predict(z_samples)
grid_col = 10
grid_row = 10

f, axarr = plt.subplots(grid_row, grid_col, figsize=(grid_col, grid_row))

i = 0
for row in range(grid_row):
    for col in range(grid_col):
        axarr[row,col].imshow(images[i,:,:,0], cmap='gray')
        axarr[row,col].axis('off')   
        i += 1
f.tight_layout(0.1, h_pad=0.2, w_pad=0.1)        
plt.show()

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
@interact
def explore_latent_variable(z1 = (-5,5,0.1),
                            z2 = (-5,5,0.1)):
    z_samples = [[z1, z2]]
    images = autoencoder_2.decoder.predict(z_samples)
    plt.figure(figsize=(2,2))
    plt.imshow(images[0,:,:,0], cmap='gray')
# Out:
# interactive(children=(FloatSlider(value=0.0, description='z1', max=5.0, min=-5.0), FloatSlider(value=0.0, desc…
