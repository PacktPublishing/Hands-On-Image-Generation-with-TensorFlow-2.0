# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Reshape, Conv2DTranspose, MaxPooling2D, UpSampling2D, LeakyReLU
from tensorflow.keras.activations import relu
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import tensorflow_datasets as tfds

import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
print("Tensorflow", tf.__version__)
# Out:
# Tensorflow 2.2.0

# %% [markdown]
# ## Load MNIST dataset

# %%
(ds_train, ds_test_), ds_info = tfds.load('mnist', 
                              split=['train', 'test'], 
                              shuffle_files=True,
                              as_supervised=True,
                              with_info=True)


batch_size = 256
def preprocess(image, label):
    image = tf.cast(image, tf.float32)
    image = image/255.
    return image, image


ds_train = ds_train.map(preprocess)
ds_train = ds_train.cache() # put dataset into memory
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(batch_size)

ds_test = ds_test_.map(preprocess).batch(batch_size).cache().prefetch(batch_size)

# %%
# return label for testing
def preprocess_with_label(image, label):
    image = tf.cast(image, tf.float32)
    image = tf.math.round(image/255.)
    return image, label

ds_test_label = ds_test_.map(preprocess_with_label).batch(1000)

# %% [markdown]
# # Building Autoencoder

# %%
def Encoder(z_dim):
    inputs  = layers.Input(shape=[28,28,1])
    
    x = inputs    
    x = Conv2D(filters=8,  kernel_size=(3,3), strides=2, padding='same', activation='relu')(x)
    x = Conv2D(filters=8,  kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
    x = Conv2D(filters=8,  kernel_size=(3,3), strides=2, padding='same', activation='relu')(x)
    x = Conv2D(filters=8,  kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
    x = Flatten()(x)
    out = Dense(z_dim)(x)
    
    return Model(inputs=inputs, outputs=out, name='encoder')

def Decoder(z_dim):
    inputs  = layers.Input(shape=[z_dim])
    x = inputs    
    x = Dense(7*7*64, activation='relu')(x)
    x = Reshape((7,7,64))(x)

    x = Conv2D(filters=64, kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
    x = UpSampling2D((2,2))(x)
    
    x = Conv2D(filters=32, kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
    x = UpSampling2D((2,2))(x)    

    out = Conv2D(filters=1, kernel_size=(3,3), strides=1, padding='same', activation='sigmoid')(x)
    
    #return out          
    return Model(inputs=inputs, outputs=out, name='decoder')

class Autoencoder:
    def __init__(self, z_dim):
        self.encoder = Encoder(z_dim)
        self.decoder = Decoder(z_dim)
        
        model_input = self.encoder.input
        model_output = self.decoder(self.encoder.output)
        self.model = Model(model_input, model_output)

# %%
autoencoder = Autoencoder(z_dim=10)

# %%
model_path = "./models/autoencoder.h5"
checkpoint = ModelCheckpoint(model_path, 
                             monitor= "val_loss", 
                             verbose=1, 
                             save_best_only=True, 
                             mode= "auto", 
                             save_weights_only = False)

early = EarlyStopping(monitor= "val_loss", 
                      mode= "auto", 
                      patience = 5)

callbacks_list = [checkpoint, early]

autoencoder.model.compile(
    loss = "bce",
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=3e-4))
    #metrics=[tf.keras.losses.BinaryCrossentropy()])
autoencoder.model.fit(ds_train, validation_data=ds_test,
                epochs = 100, callbacks = callbacks_list)
# Out:
# Epoch 1/100
# 235/235 [==============================] - ETA: 0s - loss: 0.2658
# Epoch 00001: val_loss improved from inf to 0.18209, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2658 - val_loss: 0.1821
# Epoch 2/100
# 235/235 [==============================] - ETA: 0s - loss: 0.1691
# Epoch 00002: val_loss improved from 0.18209 to 0.14860, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1691 - val_loss: 0.1486
# Epoch 3/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.1472
# Epoch 00003: val_loss improved from 0.14860 to 0.13958, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1471 - val_loss: 0.1396
# Epoch 4/100
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1379
# Epoch 00004: val_loss improved from 0.13958 to 0.13258, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1378 - val_loss: 0.1326
# Epoch 5/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.1325
# Epoch 00005: val_loss improved from 0.13258 to 0.12724, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1324 - val_loss: 0.1272
# Epoch 6/100
# 235/235 [==============================] - ETA: 0s - loss: 0.1287
# Epoch 00006: val_loss improved from 0.12724 to 0.12569, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1287 - val_loss: 0.1257
# Epoch 7/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.1259
# Epoch 00007: val_loss improved from 0.12569 to 0.12421, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1260 - val_loss: 0.1242
# Epoch 8/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1237
# Epoch 00008: val_loss improved from 0.12421 to 0.12303, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1237 - val_loss: 0.1230
# Epoch 9/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.1220
# Epoch 00009: val_loss improved from 0.12303 to 0.12149, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1219 - val_loss: 0.1215
# Epoch 10/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1205
# Epoch 00010: val_loss improved from 0.12149 to 0.11844, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1205 - val_loss: 0.1184
# Epoch 11/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.1191
# Epoch 00011: val_loss did not improve from 0.11844
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1191 - val_loss: 0.1199
# Epoch 12/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.1180
# Epoch 00012: val_loss improved from 0.11844 to 0.11633, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1180 - val_loss: 0.1163
# Epoch 13/100
# 235/235 [==============================] - ETA: 0s - loss: 0.1170
# Epoch 00013: val_loss improved from 0.11633 to 0.11440, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1170 - val_loss: 0.1144
# Epoch 14/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.1161
# Epoch 00014: val_loss did not improve from 0.11440
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1161 - val_loss: 0.1186
# Epoch 15/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.1154
# Epoch 00015: val_loss did not improve from 0.11440
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1153 - val_loss: 0.1145
# Epoch 16/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1146
# Epoch 00016: val_loss improved from 0.11440 to 0.11381, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1146 - val_loss: 0.1138
# Epoch 17/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1140
# Epoch 00017: val_loss did not improve from 0.11381
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1140 - val_loss: 0.1139
# Epoch 18/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.1133
# Epoch 00018: val_loss improved from 0.11381 to 0.11224, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1133 - val_loss: 0.1122
# Epoch 19/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1127
# Epoch 00019: val_loss improved from 0.11224 to 0.11138, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1127 - val_loss: 0.1114
# Epoch 20/100
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1122
# Epoch 00020: val_loss improved from 0.11138 to 0.11081, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1122 - val_loss: 0.1108
# Epoch 21/100
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1118
# Epoch 00021: val_loss improved from 0.11081 to 0.11079, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1118 - val_loss: 0.1108
# Epoch 22/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1113
# Epoch 00022: val_loss improved from 0.11079 to 0.11058, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1113 - val_loss: 0.1106
# Epoch 23/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.1109
# Epoch 00023: val_loss improved from 0.11058 to 0.11040, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1109 - val_loss: 0.1104
# Epoch 24/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.1105
# Epoch 00024: val_loss improved from 0.11040 to 0.10948, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1105 - val_loss: 0.1095
# Epoch 25/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.1101
# Epoch 00025: val_loss did not improve from 0.10948
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1101 - val_loss: 0.1119
# Epoch 26/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1098
# Epoch 00026: val_loss did not improve from 0.10948
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1098 - val_loss: 0.1105
# Epoch 27/100
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1094
# Epoch 00027: val_loss improved from 0.10948 to 0.10876, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1094 - val_loss: 0.1088
# Epoch 28/100
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1091
# Epoch 00028: val_loss did not improve from 0.10876
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1091 - val_loss: 0.1093
# Epoch 29/100
# 235/235 [==============================] - ETA: 0s - loss: 0.1088
# Epoch 00029: val_loss improved from 0.10876 to 0.10870, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1088 - val_loss: 0.1087
# Epoch 30/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.1085
# Epoch 00030: val_loss improved from 0.10870 to 0.10839, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1085 - val_loss: 0.1084
# Epoch 31/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.1082
# Epoch 00031: val_loss did not improve from 0.10839
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1082 - val_loss: 0.1098
# Epoch 32/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.1079
# Epoch 00032: val_loss did not improve from 0.10839
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1079 - val_loss: 0.1084
# Epoch 33/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.1076
# Epoch 00033: val_loss improved from 0.10839 to 0.10712, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1077 - val_loss: 0.1071
# Epoch 34/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.1074
# Epoch 00034: val_loss improved from 0.10712 to 0.10711, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1074 - val_loss: 0.1071
# Epoch 35/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1072
# Epoch 00035: val_loss did not improve from 0.10711
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1072 - val_loss: 0.1108
# Epoch 36/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.1070
# Epoch 00036: val_loss did not improve from 0.10711
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1070 - val_loss: 0.1101
# Epoch 37/100
# 235/235 [==============================] - ETA: 0s - loss: 0.1067
# Epoch 00037: val_loss did not improve from 0.10711
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1067 - val_loss: 0.1082
# Epoch 38/100
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1066
# Epoch 00038: val_loss did not improve from 0.10711
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1065 - val_loss: 0.1077
# Epoch 39/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.1064
# Epoch 00039: val_loss did not improve from 0.10711
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1064 - val_loss: 0.1083
# Epoch 40/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.1061
# Epoch 00040: val_loss improved from 0.10711 to 0.10613, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1061 - val_loss: 0.1061
# Epoch 41/100
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1059
# Epoch 00041: val_loss improved from 0.10613 to 0.10610, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1059 - val_loss: 0.1061
# Epoch 42/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.1058
# Epoch 00042: val_loss did not improve from 0.10610
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1058 - val_loss: 0.1071
# Epoch 43/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.1056
# Epoch 00043: val_loss improved from 0.10610 to 0.10598, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1056 - val_loss: 0.1060
# Epoch 44/100
# 235/235 [==============================] - ETA: 0s - loss: 0.1054
# Epoch 00044: val_loss did not improve from 0.10598
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1054 - val_loss: 0.1076
# Epoch 45/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1053
# Epoch 00045: val_loss did not improve from 0.10598
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1053 - val_loss: 0.1063
# Epoch 46/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.1051
# Epoch 00046: val_loss did not improve from 0.10598
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1051 - val_loss: 0.1067
# Epoch 47/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.1050
# Epoch 00047: val_loss improved from 0.10598 to 0.10518, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1050 - val_loss: 0.1052
# Epoch 48/100
# 232/235 [============================>.] - ETA: 0s - loss: 0.1048
# Epoch 00048: val_loss did not improve from 0.10518
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1048 - val_loss: 0.1069
# Epoch 49/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1046
# Epoch 00049: val_loss improved from 0.10518 to 0.10453, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1046 - val_loss: 0.1045
# Epoch 50/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.1046
# Epoch 00050: val_loss did not improve from 0.10453
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1045 - val_loss: 0.1050
# Epoch 51/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.1044
# Epoch 00051: val_loss did not improve from 0.10453
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1044 - val_loss: 0.1048
# Epoch 52/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.1042
# Epoch 00052: val_loss did not improve from 0.10453
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1042 - val_loss: 0.1057
# Epoch 53/100
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1041
# Epoch 00053: val_loss did not improve from 0.10453
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1041 - val_loss: 0.1060
# Epoch 54/100
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1040
# Epoch 00054: val_loss improved from 0.10453 to 0.10399, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1040 - val_loss: 0.1040
# Epoch 55/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1039
# Epoch 00055: val_loss did not improve from 0.10399
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1039 - val_loss: 0.1057
# Epoch 56/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.1038
# Epoch 00056: val_loss did not improve from 0.10399
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1037 - val_loss: 0.1049
# Epoch 57/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.1036
# Epoch 00057: val_loss did not improve from 0.10399
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1036 - val_loss: 0.1049
# Epoch 58/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.1035
# Epoch 00058: val_loss improved from 0.10399 to 0.10386, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1035 - val_loss: 0.1039
# Epoch 59/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1034
# Epoch 00059: val_loss did not improve from 0.10386
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1034 - val_loss: 0.1042
# Epoch 60/100
# 231/235 [============================>.] - ETA: 0s - loss: 0.1033
# Epoch 00060: val_loss did not improve from 0.10386
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1033 - val_loss: 0.1044
# Epoch 61/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1032
# Epoch 00061: val_loss improved from 0.10386 to 0.10385, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1032 - val_loss: 0.1038
# Epoch 62/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.1031
# Epoch 00062: val_loss did not improve from 0.10385
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1031 - val_loss: 0.1039
# Epoch 63/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.1030
# Epoch 00063: val_loss did not improve from 0.10385
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1030 - val_loss: 0.1056
# Epoch 64/100
# 235/235 [==============================] - ETA: 0s - loss: 0.1028
# Epoch 00064: val_loss did not improve from 0.10385
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1028 - val_loss: 0.1042
# Epoch 65/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.1027
# Epoch 00065: val_loss did not improve from 0.10385
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1027 - val_loss: 0.1042
# Epoch 66/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.1026
# Epoch 00066: val_loss improved from 0.10385 to 0.10274, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 2s 6ms/step - loss: 0.1026 - val_loss: 0.1027
# Epoch 67/100
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1026
# Epoch 00067: val_loss did not improve from 0.10274
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1025 - val_loss: 0.1049
# Epoch 68/100
# 230/235 [============================>.] - ETA: 0s - loss: 0.1025
# Epoch 00068: val_loss did not improve from 0.10274
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1025 - val_loss: 0.1036
# Epoch 69/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1023
# Epoch 00069: val_loss did not improve from 0.10274
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1023 - val_loss: 0.1036
# Epoch 70/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.1023
# Epoch 00070: val_loss did not improve from 0.10274
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1022 - val_loss: 0.1037
# Epoch 71/100
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1022
# Epoch 00071: val_loss did not improve from 0.10274
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1022 - val_loss: 0.1031
# Epoch 72/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.1021
# Epoch 00072: val_loss did not improve from 0.10274
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1021 - val_loss: 0.1033
# Epoch 73/100
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1020
# Epoch 00073: val_loss did not improve from 0.10274
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1020 - val_loss: 0.1032
# Epoch 74/100
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1019
# Epoch 00074: val_loss improved from 0.10274 to 0.10257, saving model to ./models/autoencoder.h5
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1019 - val_loss: 0.1026
# Epoch 75/100
# 229/235 [============================>.] - ETA: 0s - loss: 0.1018
# Epoch 00075: val_loss did not improve from 0.10257
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1018 - val_loss: 0.1033
# Epoch 76/100
# 234/235 [============================>.] - ETA: 0s - loss: 0.1018
# Epoch 00076: val_loss did not improve from 0.10257
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1018 - val_loss: 0.1032
# Epoch 77/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.1017
# Epoch 00077: val_loss did not improve from 0.10257
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1017 - val_loss: 0.1029
# Epoch 78/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.1016
# Epoch 00078: val_loss did not improve from 0.10257
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1016 - val_loss: 0.1035
# Epoch 79/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.1015
# Epoch 00079: val_loss did not improve from 0.10257
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1015 - val_loss: 0.1031
# Epoch 80/100
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1015
# Epoch 00080: val_loss did not improve from 0.10257
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1015 - val_loss: 0.1028
# Epoch 81/100
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1014
# Epoch 00081: val_loss did not improve from 0.10257
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1014 - val_loss: 0.1037
# Epoch 82/100
# 233/235 [============================>.] - ETA: 0s - loss: 0.1013
# Epoch 00082: val_loss did not improve from 0.10257
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1013 - val_loss: 0.1028
# Epoch 83/100
# 228/235 [============================>.] - ETA: 0s - loss: 0.1013
# Epoch 00083: val_loss did not improve from 0.10257
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1012 - val_loss: 0.1032
# Epoch 84/100
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1011
# Epoch 00084: val_loss did not improve from 0.10257
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1012 - val_loss: 0.1033

# %% [markdown]
# # Sample and Display Images

# %%
images, labels = next(iter(ds_test))
autoencoder.model = load_model(model_path)
outputs = autoencoder.model.predict(images)

# Display
grid_col = 10
grid_row = 2

f, axarr = plt.subplots(grid_row, grid_col, figsize=(grid_col*1.1, grid_row))

i = 0
for row in range(0, grid_row, 2):
    for col in range(grid_col):
        axarr[row,col].imshow(images[i,:,:,0], cmap='gray')
        axarr[row,col].axis('off')
        axarr[row+1,col].imshow(outputs[i,:,:,0], cmap='gray')
        axarr[row+1,col].axis('off')        
        i += 1
f.tight_layout(0.1, h_pad=0.2, w_pad=0.1)        
plt.show()

# %% [markdown]
# ## Set z_dim = 2 and to look at the latent variables

# %%
autoencoder_2 = Autoencoder(z_dim=2)

early = EarlyStopping(monitor= "val_loss", 
                      mode= "auto", 
                      patience = 5)

callbacks_list = [early]

autoencoder_2.model.compile(
    loss = "bce",
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-3))

autoencoder_2.model.fit(ds_train, validation_data=ds_test,
                epochs = 50, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2593 - val_loss: 0.2213
# Epoch 2/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2152 - val_loss: 0.2117
# Epoch 3/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2074 - val_loss: 0.2040
# Epoch 4/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2031 - val_loss: 0.2001
# Epoch 5/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1999 - val_loss: 0.1999
# Epoch 6/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1977 - val_loss: 0.1983
# Epoch 7/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1961 - val_loss: 0.1954
# Epoch 8/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1947 - val_loss: 0.1933
# Epoch 9/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1935 - val_loss: 0.1975
# Epoch 10/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1924 - val_loss: 0.1932
# Epoch 11/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1915 - val_loss: 0.1929
# Epoch 12/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1907 - val_loss: 0.1894
# Epoch 13/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1900 - val_loss: 0.1884
# Epoch 14/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1894 - val_loss: 0.1902
# Epoch 15/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1889 - val_loss: 0.1900
# Epoch 16/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1883 - val_loss: 0.1881
# Epoch 17/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1879 - val_loss: 0.1881
# Epoch 18/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1875 - val_loss: 0.1877
# Epoch 19/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1871 - val_loss: 0.1875
# Epoch 20/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1867 - val_loss: 0.1879
# Epoch 21/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1864 - val_loss: 0.1864
# Epoch 22/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1860 - val_loss: 0.1858
# Epoch 23/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1857 - val_loss: 0.1860
# Epoch 24/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1854 - val_loss: 0.1858
# Epoch 25/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1850 - val_loss: 0.1849
# Epoch 26/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1848 - val_loss: 0.1860
# Epoch 27/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1845 - val_loss: 0.1839
# Epoch 28/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1842 - val_loss: 0.1864
# Epoch 29/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1840 - val_loss: 0.1850
# Epoch 30/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1837 - val_loss: 0.1854
# Epoch 31/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1836 - val_loss: 0.1843
# Epoch 32/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1834 - val_loss: 0.1862

# %%
images, labels = next(iter(ds_test_label))
outputs = autoencoder_2.encoder.predict(images)
plt.figure(figsize=(8,8))
plt.scatter(outputs[:,0], outputs[:,1], c=labels, cmap='RdYlBu', s=3)
plt.colorbar()

# %%
z_samples = np.array([[z1, z2] for z2 in np.arange(-5, 5, 1.) for z1 in np.arange(-5, 5, 1.)])
images = autoencoder_2.decoder.predict(z_samples)
grid_col = 10
grid_row = 10

f, axarr = plt.subplots(grid_row, grid_col, figsize=(grid_col, grid_row))

i = 0
for row in range(grid_row):
    for col in range(grid_col):
        axarr[row,col].imshow(images[i,:,:,0], cmap='gray')
        axarr[row,col].axis('off')   
        i += 1
f.tight_layout(0.1, h_pad=0.2, w_pad=0.1)        
plt.show()

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
@interact
def explore_latent_variable(z1 = (-5,5,0.1),
                            z2 = (-5,5,0.1)):
    z_samples = [[z1, z2]]
    images = autoencoder_2.decoder.predict(z_samples)
    plt.figure(figsize=(2,2))
    plt.imshow(images[0,:,:,0], cmap='gray')
# Out:
# interactive(children=(FloatSlider(value=0.0, description='z1', max=5.0, min=-5.0), FloatSlider(value=0.0, desc…
